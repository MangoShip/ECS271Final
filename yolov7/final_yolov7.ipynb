# %%
# !git clone https://github.com/WongKinYiu/yolov7.git

# %%
# %cd /content/drive/MyDrive/Fall 2022/ECS271/yolov7

# %%
# !pip install --upgrade pip

# %%
# !pip3 install -r requirements.txt

# %%
# !pip install torch

# %%
# !sudo apt install -y zip htop screen libgl1-mesa-glx

# %% [markdown]
# Transfer learning

# %%
# !python train.py --weights yolov7.pt --data "data/custom.yaml" --workers 4 --batch-size 4 --cfg cfg/training/yolov7.yaml --name yolov7 --hyp data/hyp.scratch.p5.yaml --epochs 1

# %% [markdown]
# Testing the learned model

# %%
# !python detect.py --weights /content/drive/MyDrive/Fall\ 2022/ECS271/yolov7/runs/train/yolo_gpu_20epochs/best.pt --source /content/drive/MyDrive/Fall\ 2022/ECS271/yolov7/Sohas_weapon-Detection-YOLO/obj_train_data/images/test/
